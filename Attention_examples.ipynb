# %%
import os

# google colab 사용 시 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # Sequence-to-sequence with attention

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer')

# %run main_seq2seq.py
# Out:
# Reading lines...
# Read 5890 sentence pairs
# Trimmed to 516 sentence pairs
# Counting words...
# Counted words:
# kor 992
# eng 599
# 0m 9s (- 6m 0s) (5 2%) 4.0556
# 0m 12s (- 3m 50s) (10 5%) 2.9697
# 0m 14s (- 2m 54s) (15 7%) 2.3847
# 0m 16s (- 2m 25s) (20 10%) 1.9473
# 0m 18s (- 2m 6s) (25 12%) 1.5603
# 0m 20s (- 1m 53s) (30 15%) 1.2161
# 0m 22s (- 1m 44s) (35 17%) 0.9470
# 0m 24s (- 1m 38s) (40 20%) 0.7338
# 0m 27s (- 1m 33s) (45 22%) 0.5699
# 0m 28s (- 1m 26s) (50 25%) 0.4345
# 0m 30s (- 1m 21s) (55 27%) 0.3313
# 0m 32s (- 1m 16s) (60 30%) 0.2493
# 0m 34s (- 1m 12s) (65 32%) 0.1912
# 0m 37s (- 1m 9s) (70 35%) 0.1493
# 0m 39s (- 1m 6s) (75 37%) 0.1159
# 0m 41s (- 1m 2s) (80 40%) 0.0926
# 0m 43s (- 0m 59s) (85 42%) 0.0789
# 0m 45s (- 0m 56s) (90 45%) 0.0637
# 0m 47s (- 0m 52s) (95 47%) 0.0537
# 0m 49s (- 0m 49s) (100 50%) 0.0480
# 0m 52s (- 0m 47s) (105 52%) 0.0416
# 0m 54s (- 0m 44s) (110 55%) 0.0386
# 0m 56s (- 0m 41s) (115 57%) 0.0349
# 0m 58s (- 0m 39s) (120 60%) 0.0314
# 1m 0s (- 0m 36s) (125 62%) 0.0291
# 1m 2s (- 0m 33s) (130 65%) 0.0276
# 1m 5s (- 0m 31s) (135 67%) 0.0259
# 1m 7s (- 0m 28s) (140 70%) 0.0254
# 1m 9s (- 0m 26s) (145 72%) 0.0220
# 1m 11s (- 0m 23s) (150 75%) 0.0210
# 1m 13s (- 0m 21s) (155 77%) 0.0205
# 1m 15s (- 0m 18s) (160 80%) 0.0228
# 1m 17s (- 0m 16s) (165 82%) 0.0190
# 1m 20s (- 0m 14s) (170 85%) 0.0185
# 1m 22s (- 0m 11s) (175 87%) 0.0201
# 1m 23s (- 0m 9s) (180 90%) 0.0185
# 1m 25s (- 0m 6s) (185 92%) 0.0165
# 1m 27s (- 0m 4s) (190 95%) 0.0170
# 1m 29s (- 0m 2s) (195 97%) 0.0153
# 1m 32s (- 0m 0s) (200 100%) 0.0146
# > 틀림없어 !
# = i m absolutely sure !
# < with mary mary person doctor <EOS>
#
# > 걔는 항상 반에서 꼴찌야
# = she is always at the bottom of the class
# < she is always at the bottom of the meaning class
#
# > 잠잘 시간이야
# = it s time to go to bed
# < i m happy to bed time to bed good night
#
# > 나는 방에서 프랑스어 공부하는 중이야
# = i m in my room studying french
# < i m in my room studying french studying french days
#
# > 난 그 인간을 쏠 거야
# = i m going to shoot that guy
# < i m going to shoot that guy tomorrow afternoon <EOS>
#
# > 나는 지구 상에서 가장 행복한 사람이었다
# = i was the happiest man on earth
# < i was the happiest man on earth on earth earth
#
# > 난 그냥 티비 보고 있어
# = i m just watching television
# < i m just watching television unavoidable ? isn t teaching
#
# > 이건 톰 탓이야
# = it was tom s fault
# < it was tom s favorite french word fault <EOS>
#
# > 그녀는 대범하다
# = she is easygoing
# < she is easygoing easygoing easygoing doctor <EOS>
#
# > 눈이 와요
# = it s snowing
# < it s snowing <EOS>

# %% [markdown]
# # Transformer

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer')

# %run main_transformer.py
# Out:
# Reading lines...
# Read 5890 sentence pairs
# Trimmed to 516 sentence pairs
# Counting words...
# Counted words:
# kor 992
# eng 599
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py:6041: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# 0m 34s (- 2m 53s) (100 16%) 1.4020
# 1m 2s (- 2m 5s) (200 33%) 0.2723
# 1m 30s (- 1m 30s) (300 50%) 0.1550
# 1m 58s (- 0m 59s) (400 66%) 0.1144
# 2m 25s (- 0m 29s) (500 83%) 0.0945
# 2m 53s (- 0m 0s) (600 100%) 0.0813
# > 죄송하지만 무슨 말인지 모르겠어요
# = i m sorry but i don t understand
# < i m sorry but i don t understand EOS
#
# > 그는 순진했다
# = she was naive
# < she was naive EOS
#
# > 나는 수감되었다
# = i m in jail
# < i m in jail EOS
#
# > 그들은 운이 좋았다
# = they were lucky
# < they were lucky EOS
#
# > 네가 부정하지 못할 사실이다
# = it s a fact you can t deny
# < it s a fact you can t deny EOS
#
# > 난 그저 최선을 다하고 있을 뿐이다
# = i m just doing my best
# < i m just doing my best EOS
#
# > 나는 편지를 쓰고 있다
# = i m writing a letter
# < i m writing a letter EOS
#
# > 안개가 꼈다
# = it is foggy
# < it is foggy EOS
#
# > 초록색이야
# = they re green
# < they re green EOS
#
# > 그들은 선생님이다
# = they are teachers
# < they are teachers EOS
