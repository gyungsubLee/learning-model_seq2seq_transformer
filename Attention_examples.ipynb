# %%
import os

# google colab 사용 시 구글 드라이브 마운트
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # Sequence-to-sequence with attention

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer')

# %run main_seq2seq.py
# Out:
# Reading lines...
# Read 5890 sentence pairs
# Trimmed to 516 sentence pairs
# Counting words...
# Counted words:
# kor 992
# eng 599
# 0m 1s (- 1m 3s) (5 2%) 4.1068
# 0m 3s (- 1m 9s) (10 5%) 2.9928
# 0m 5s (- 1m 10s) (15 7%) 2.3766
# 0m 7s (- 1m 6s) (20 10%) 1.8810
# 0m 8s (- 1m 2s) (25 12%) 1.4555
# 0m 10s (- 1m 0s) (30 15%) 1.1175
# 0m 12s (- 0m 57s) (35 17%) 0.8431
# 0m 13s (- 0m 55s) (40 20%) 0.6362
# 0m 15s (- 0m 53s) (45 22%) 0.4769
# 0m 17s (- 0m 53s) (50 25%) 0.3582
# 0m 19s (- 0m 51s) (55 27%) 0.2634
# 0m 21s (- 0m 49s) (60 30%) 0.1976
# 0m 22s (- 0m 47s) (65 32%) 0.1538
# 0m 24s (- 0m 45s) (70 35%) 0.1175
# 0m 25s (- 0m 43s) (75 37%) 0.0908
# 0m 27s (- 0m 41s) (80 40%) 0.0743
# 0m 29s (- 0m 40s) (85 42%) 0.0662
# 0m 31s (- 0m 38s) (90 45%) 0.0540
# 0m 33s (- 0m 36s) (95 47%) 0.0478
# 0m 34s (- 0m 34s) (100 50%) 0.0421
# 0m 36s (- 0m 32s) (105 52%) 0.0404
# 0m 38s (- 0m 31s) (110 55%) 0.0360
# 0m 39s (- 0m 29s) (115 57%) 0.0314
# 0m 41s (- 0m 27s) (120 60%) 0.0287
# ...

# %% [markdown]
# # Transformer

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer')

# %run main_transformer.py
# Out:
# Reading lines...
# Read 5890 sentence pairs
# Trimmed to 516 sentence pairs
# Counting words...
# Counted words:
# kor 992
# eng 599
# 0m 29s (- 2m 25s) (100 16%) 1.3661
# 0m 57s (- 1m 54s) (200 33%) 0.2474
# 1m 25s (- 1m 25s) (300 50%) 0.1444
# 1m 53s (- 0m 56s) (400 66%) 0.1095
# 2m 22s (- 0m 28s) (500 83%) 0.0909
# 2m 51s (- 0m 0s) (600 100%) 0.0774
# > 어쩔 수 없었지 않니 ?
# = it was inevitable wasn t it ?
# < it was inevitable wasn t it ? EOS
#
# > 그는 물에 빠져 죽을 뻔 했다
# = he was nearly drowned
# < he was nearly drowned EOS
#
# > 그들은 채식주의자이다
# = they re vegetarians
# < they re vegetarians EOS
#
# > 창피해
# = i m embarrassed
# < i m embarrassed EOS
#
# > 톰은 거기에 갈 거라고 확신해
# = i m sure tom is going to be there
# < i m sure tom is going to be there EOS
#
# > 나는 자살하고 싶지 않다
# = i m not suicidal
# < i m not suicidal EOS
#
# > 내가 울어서 미안해
# = i m sorry that i cried
# < i m sorry that i cried EOS
#
# ...
