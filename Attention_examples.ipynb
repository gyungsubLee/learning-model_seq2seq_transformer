# %%
import os

# google colab 사용 시 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # Sequence-to-sequence with attention

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer')

# %run main_seq2seq.py
# Out:
# Reading lines...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer/main_seq2seq.py in <module>
#     153     # target_lang = 'fra'
#     154
# --> 155     input_lang, output_lang, train_dataloader, pairs = get_dataloader(batch_size, target_lang=target_lang)
#     156
#     157     encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
#
# /content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer/main_seq2seq.py in get_dataloader(batch_size, target_lang)
#      30
#      31 def get_dataloader(batch_size, target_lang='fra'):
# ---> 32     input_lang, output_lang, pairs = prepareData('eng', target_lang, True)
#      33
#      34     n = len(pairs)
#
# /content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer/language_processor.py in prepareData(lang1, lang2, reverse)
#     128 # The full process for preparing the data
#     129 def prepareData(lang1, lang2, reverse=False):
# --> 130     input_lang, output_lang, pairs = readLangs(lang1, lang2,
#     131                                                reverse)  # 1. Read text file and split into lines, split lines into pairs
#     132     print("Read %s sentence pairs" % len(pairs))
#
# /content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer/language_processor.py in readLangs(lang1, lang2, reverse)
#      72
#      73     # Read the file and split into lines
# ---> 74     lines = open('data/%s-%s.txt' % (lang1, lang2), encoding='utf-8'). \
#      75         read().strip().split('\n')
#      76
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/eng-kor.txt'

# %% [markdown]
# # Transformer

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/translation_w_seq2seq_n_transformer')

# %run main_transformer.py
# Out:
# Reading lines...
# Read 5890 sentence pairs
# Trimmed to 516 sentence pairs
# Counting words...
# Counted words:
# kor 992
# eng 599
# 0m 29s (- 2m 25s) (100 16%) 1.3661
# 0m 57s (- 1m 54s) (200 33%) 0.2474
# 1m 25s (- 1m 25s) (300 50%) 0.1444
# 1m 53s (- 0m 56s) (400 66%) 0.1095
# 2m 22s (- 0m 28s) (500 83%) 0.0909
# 2m 51s (- 0m 0s) (600 100%) 0.0774
# > 어쩔 수 없었지 않니 ?
# = it was inevitable wasn t it ?
# < it was inevitable wasn t it ? EOS
#
# > 그는 물에 빠져 죽을 뻔 했다
# = he was nearly drowned
# < he was nearly drowned EOS
#
# > 그들은 채식주의자이다
# = they re vegetarians
# < they re vegetarians EOS
#
# > 창피해
# = i m embarrassed
# < i m embarrassed EOS
#
# > 톰은 거기에 갈 거라고 확신해
# = i m sure tom is going to be there
# < i m sure tom is going to be there EOS
#
# > 나는 자살하고 싶지 않다
# = i m not suicidal
# < i m not suicidal EOS
#
# > 내가 울어서 미안해
# = i m sorry that i cried
# < i m sorry that i cried EOS
#
# > 그건 네가 생각하는 만큼 어려운 건 아냐
# = it s not as hard as you think
# < it s not as difficult as you think EOS
#
# > 우리는 다 같은 처지에 있지 않는다
# = we re not all in the same boat
# < we re not all in the same boat EOS
#
# > 망나니처럼 행동해서 미안해
# = i m sorry that i acted like a jerk
# < i m sorry i acted like a jerk EOS
